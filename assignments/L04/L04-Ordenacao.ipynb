# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/glaucogoncalves/p-e/blob/main/assignments/L04/L04-Ordenacao.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# #Lab03
#
# Estudante: Seu nome aqui

# %% [markdown]
# ## Cenário
#
# Os algoritmos de ordenação são a base do funcionamento de diversos algoritmos e de sistemas de informação modernos. Por isso, tais algoritmos são tão importantes para a computação. Você deve ter aprendido que existem diversos algoritmos de ordenação e que cada um é mais apropriado para cada cenário.
#
# Neste laboratório iremos construir um experimento para avaliar algoritmos de ordenação. A proposta deste laboratório não é trabalhar os algoritmos em si, mas sim treinar as habilidades de definição e execução de um experimento estatístico. Por isso, abaixo são fornecidas as implementações de três algoritmos de ordenação: Quicksort, MergeSort e Heapsort.

# %%
import heapq

def quicksort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quicksort(left) + middle + quicksort(right)

def mergesort(arr):
    if len(arr) <= 1:
        return arr
    mid = len(arr) // 2
    left = arr[:mid]
    right = arr[mid:]
    return merge(mergesort(left), mergesort(right))

def merge(left, right):
    result = []
    i = j = 0
    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1
    result.extend(left[i:])
    result.extend(right[j:])
    return result

def heapsort(arr):
    h = []
    for value in arr:
        heapq.heappush(h, value)
    return [heapq.heappop(h) for i in range(len(h))]

# %% [markdown]
# Seu trabalho consiste em elaborar um experimento estatístico com dois fatores para avaliar o desempenho destes algoritmos. Devem ser usados como fatores deste experimento: o algoritmo de ordenação e o nível de desordem da entrada. Realize os experimentos, capturando os tempos de execução dos algoritmos, esta será sua métrica. Aplique os testes e análises que vimos em sala para estes experimentos.
#
# O nível de desordem da entrada é uma forma de criar diferentes cenários para os algoritmos. Sabemos que, para alguns algoritmos, se a lista passada na entrada já está parcialmente ordenada, o algoritmo de ordenação tende a realizar suas atividades em menor tempo, como mostra a tabela abaixo. O que este fator deve refletir é justamente isso. Procure estabelecer entradas que representem o melhor caso, o caso médio e o pior caso.
#
# Um parâmetro importante no experimento é o tamanho da lista de entrada. Pense bem em quais valores utilizar.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Experimento

# %% [markdown]
# Sua resposta aqui

# %% [markdown]
# # Conclusão
#
# Agora é o momento de pensar sobre os resultados. Procure discutir abaixo os resultados obtidos, interpretando os resultados do teste de hipótese. Procure ainda comparar os resultados que você obteve com as complexidades teóricas dos algoritmos de ordenação.

# %% [markdown]
# Sua resposta aqui
